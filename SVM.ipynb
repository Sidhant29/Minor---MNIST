# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.svm import LinearSVC
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import accuracy_score
from keras.datasets import mnist
# Out:
# Using TensorFlow backend.

# %%
(x,y),(x_,y_) = mnist.load_data()
x = x.reshape(-1,784)
x_ = x_.reshape(-1,784)
y = y
y_ = y_
print (x.shape,y.shape)
print (x_.shape,y_.shape)
# Out:
# (60000, 784) (60000,)
# (10000, 784) (10000,)

# %%
split = int(x.shape[0]*0.80)

x_train = x[:split]
y_train = y[:split]
x_val = x[split:]
y_val = y[split:]
x_test = x_ 
y_test = y_

print (x_train.shape, x_val.shape, x_test.shape)
print (y_train.shape, y_val.shape, y_test.shape)
# Out:
# (48000, 784) (12000, 784) (10000, 784)
# (48000,) (12000,) (10000,)

# %%
clf_svm = LinearSVC()
clf_svm.fit(x, y)
# Out:
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0)

# %%
y1 = clf_svm.predict(x_train)
acc1 = accuracy_score(y_train, y1)

y2 = clf_svm.predict(x_val)
acc2 = accuracy_score(y_val, y2)

y3 = clf_svm.predict(x_test)
acc3 = accuracy_score(y_test, y3)

# %%
print ("Training Data")
print ("Number of samples : ", x_train.shape[0])
print ("Accuracy : ", acc1)
print ()

print ("Validation Data")
print ("Number of samples : ", x_val.shape[0])
print ("Accuracy : ", acc2)
print ()

print ("Testing Data")
print ("Number of samples : ", x_test.shape[0])
print ("Accuracy : ", acc3)
# Out:
# Training Data
# Number of samples :  48000
# Accuracy :  0.8655416666666667
#
# Validation Data
# Number of samples :  12000
# Accuracy :  0.8749166666666667
#
# Testing Data
# Number of samples :  10000
# Accuracy :  0.8595
